# %% [markdown]
# # Image features exercise
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://iie.fing.edu.uy/~mdelbra/DL2016) on the course website.*
#
# We have seen that we can achieve reasonable performance on an image classification task by training a linear classifier on the pixels of the input image. In this exercise we will show that we can improve our classification performance by training linear classifiers not on raw pixels but on features that are computed from the raw pixels.
#
# All of your work for this exercise will be done in this notebook.

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Load data
# Similar to previous exercises, we will load CIFAR-10 data from disk.

# %%
from cs231n.features import color_histogram_hsv, hog_feature

def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000):
  # Load the raw CIFAR-10 data
  cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
  X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
  
  # Subsample the data
  mask = range(num_training, num_training + num_validation)
  X_val = X_train[mask]
  y_val = y_train[mask]
  mask = range(num_training)
  X_train = X_train[mask]
  y_train = y_train[mask]
  mask = range(num_test)
  X_test = X_test[mask]
  y_test = y_test[mask]

  return X_train, y_train, X_val, y_val, X_test, y_test

X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()

# %% [markdown]
# ## Extract Features
# For each image we will compute a Histogram of Oriented
# Gradients (HOG) as well as a color histogram using the hue channel in HSV
# color space. We form our final feature vector for each image by concatenating
# the HOG and color histogram feature vectors.
#
# Roughly speaking, HOG should capture the texture of the image while ignoring
# color information, and the color histogram represents the color of the input
# image while ignoring texture. As a result, we expect that using both together
# ought to work better than using either alone. Verifying this assumption would
# be a good thing to try for the bonus section.
#
# The `hog_feature` and `color_histogram_hsv` functions both operate on a single
# image and return a feature vector for that image. The extract_features
# function takes a set of images and a list of feature functions and evaluates
# each feature function on each image, storing the results in a matrix where
# each column is the concatenation of all feature vectors for a single image.

# %%
from cs231n.features import *

num_color_bins = 10 # Number of bins in the color histogram
feature_fns = [hog_feature, lambda img: color_histogram_hsv(img, nbin=num_color_bins)]
X_train_feats = extract_features(X_train, feature_fns, verbose=True)
X_val_feats = extract_features(X_val, feature_fns)
X_test_feats = extract_features(X_test, feature_fns)

# Preprocessing: Subtract the mean feature
mean_feat = np.mean(X_train_feats, axis=0, keepdims=True)
X_train_feats -= mean_feat
X_val_feats -= mean_feat
X_test_feats -= mean_feat

# Preprocessing: Divide by standard deviation. This ensures that each feature
# has roughly the same scale.
std_feat = np.std(X_train_feats, axis=0, keepdims=True)
X_train_feats /= std_feat
X_val_feats /= std_feat
X_test_feats /= std_feat

# Preprocessing: Add a bias dimension
X_train_feats = np.hstack([X_train_feats, np.ones((X_train_feats.shape[0], 1))])
X_val_feats = np.hstack([X_val_feats, np.ones((X_val_feats.shape[0], 1))])
X_test_feats = np.hstack([X_test_feats, np.ones((X_test_feats.shape[0], 1))])
# Out:
# Done extracting features for 1000 / 49000 images
# Done extracting features for 2000 / 49000 images
# Done extracting features for 3000 / 49000 images
# Done extracting features for 4000 / 49000 images
# Done extracting features for 5000 / 49000 images
# Done extracting features for 6000 / 49000 images
# Done extracting features for 7000 / 49000 images
# Done extracting features for 8000 / 49000 images
# Done extracting features for 9000 / 49000 images
# Done extracting features for 10000 / 49000 images
# Done extracting features for 11000 / 49000 images
# Done extracting features for 12000 / 49000 images
# Done extracting features for 13000 / 49000 images
# Done extracting features for 14000 / 49000 images
# Done extracting features for 15000 / 49000 images
# Done extracting features for 16000 / 49000 images
# Done extracting features for 17000 / 49000 images
# Done extracting features for 18000 / 49000 images
# Done extracting features for 19000 / 49000 images
# Done extracting features for 20000 / 49000 images
# Done extracting features for 21000 / 49000 images
# Done extracting features for 22000 / 49000 images
# Done extracting features for 23000 / 49000 images
# Done extracting features for 24000 / 49000 images
# Done extracting features for 25000 / 49000 images
# Done extracting features for 26000 / 49000 images
# Done extracting features for 27000 / 49000 images
# Done extracting features for 28000 / 49000 images
# Done extracting features for 29000 / 49000 images
# Done extracting features for 30000 / 49000 images
# Done extracting features for 31000 / 49000 images
# Done extracting features for 32000 / 49000 images
# Done extracting features for 33000 / 49000 images
# Done extracting features for 34000 / 49000 images
# Done extracting features for 35000 / 49000 images
# Done extracting features for 36000 / 49000 images
# Done extracting features for 37000 / 49000 images
# Done extracting features for 38000 / 49000 images
# Done extracting features for 39000 / 49000 images
# Done extracting features for 40000 / 49000 images
# Done extracting features for 41000 / 49000 images
# Done extracting features for 42000 / 49000 images
# Done extracting features for 43000 / 49000 images
# Done extracting features for 44000 / 49000 images
# Done extracting features for 45000 / 49000 images
# Done extracting features for 46000 / 49000 images
# Done extracting features for 47000 / 49000 images
# Done extracting features for 48000 / 49000 images

# %% [markdown]
# ## Train Softmax on features
# Using the multiclass Softmax code developed earlier in the assignment, train SoftMaxs on top of the features extracted above; this should achieve better results than training SoftMaxs directly on top of raw pixels.

# %%
# Use the validation set to tune the learning rate and regularization strength

from cs231n.classifiers.linear_classifier import Softmax

learning_rates = [1e-9, 1e-8, 1e-7]
regularization_strengths = [1e5, 1e6, 1e7]

results = {}
best_val = -1
best_softmax = None

pass
################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the Softmax;     #
# save the best trained classifer in best_softmax. You might also want to play #
# with different numbers of bins in the color histogram. If you are careful    #
# you should be able to get accuracy of near [0.42] on the validation set.     #
################################################################################
best_num_color_bins = None

for num_color_bins in [5, 10, 15]:
    feature_fns = [hog_feature, lambda img: color_histogram_hsv(img, nbin=num_color_bins)]
    X_train_feats = extract_features(X_train, feature_fns, verbose=True)
    X_val_feats = extract_features(X_val, feature_fns)
    X_test_feats = extract_features(X_test, feature_fns)

    # Preprocessing: Subtract the mean feature
    mean_feat = np.mean(X_train_feats, axis=0, keepdims=True)
    X_train_feats -= mean_feat
    X_val_feats -= mean_feat
    X_test_feats -= mean_feat

    # Preprocessing: Divide by standard deviation. This ensures that each feature
    # has roughly the same scale.
    std_feat = np.std(X_train_feats, axis=0, keepdims=True)
    X_train_feats /= std_feat
    X_val_feats /= std_feat
    X_test_feats /= std_feat

    # Preprocessing: Add a bias dimension
    X_train_feats = np.hstack([X_train_feats, np.ones((X_train_feats.shape[0], 1))])
    X_val_feats = np.hstack([X_val_feats, np.ones((X_val_feats.shape[0], 1))])
    X_test_feats = np.hstack([X_test_feats, np.ones((X_test_feats.shape[0], 1))])
    
    
    for learning_rate in learning_rates:
        for reg in regularization_strengths:
            softmax = Softmax()
            loss_hist = softmax.train(X_train_feats, y_train, learning_rate=learning_rate, reg=reg,
                                      num_iters=1000, verbose=True)
            y_train_pred = softmax.predict(X_train_feats)
            y_val_pred = softmax.predict(X_val_feats)
            acc_train = np.mean(y_train == y_train_pred)
            acc_val = np.mean(y_val == y_val_pred)
            results[(learning_rate, reg)] = (acc_train, acc_val)
            if best_val < acc_val:
                best_val = acc_val
                best_softmax = softmax
                best_num_color_bins = num_color_bins

print 'best number of bins: %d' % best_num_color_bins
################################################################################
#                              END OF YOUR CODE                                #
################################################################################

# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print 'lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy)
    
print 'best validation accuracy achieved during cross-validation: %f' % best_val
# Out:
# Done extracting features for 1000 / 49000 images
# Done extracting features for 2000 / 49000 images
# Done extracting features for 3000 / 49000 images
# Done extracting features for 4000 / 49000 images
# Done extracting features for 5000 / 49000 images
# Done extracting features for 6000 / 49000 images
# Done extracting features for 7000 / 49000 images
# Done extracting features for 8000 / 49000 images
# Done extracting features for 9000 / 49000 images
# Done extracting features for 10000 / 49000 images
# Done extracting features for 11000 / 49000 images
# Done extracting features for 12000 / 49000 images
# Done extracting features for 13000 / 49000 images
# Done extracting features for 14000 / 49000 images
# Done extracting features for 15000 / 49000 images
# Done extracting features for 16000 / 49000 images
# Done extracting features for 17000 / 49000 images
# Done extracting features for 18000 / 49000 images
# Done extracting features for 19000 / 49000 images
# Done extracting features for 20000 / 49000 images
# Done extracting features for 21000 / 49000 images
# Done extracting features for 22000 / 49000 images
# Done extracting features for 23000 / 49000 images
# Done extracting features for 24000 / 49000 images
# Done extracting features for 25000 / 49000 images
# Done extracting features for 26000 / 49000 images
# Done extracting features for 27000 / 49000 images
# Done extracting features for 28000 / 49000 images
# Done extracting features for 29000 / 49000 images
# Done extracting features for 30000 / 49000 images
# Done extracting features for 31000 / 49000 images
# Done extracting features for 32000 / 49000 images
# Done extracting features for 33000 / 49000 images
# Done extracting features for 34000 / 49000 images
# Done extracting features for 35000 / 49000 images
# Done extracting features for 36000 / 49000 images
# Done extracting features for 37000 / 49000 images
# Done extracting features for 38000 / 49000 images
# Done extracting features for 39000 / 49000 images
# Done extracting features for 40000 / 49000 images
# Done extracting features for 41000 / 49000 images
# Done extracting features for 42000 / 49000 images
# Done extracting features for 43000 / 49000 images
# Done extracting features for 44000 / 49000 images
# Done extracting features for 45000 / 49000 images
# Done extracting features for 46000 / 49000 images
# Done extracting features for 47000 / 49000 images
# Done extracting features for 48000 / 49000 images
# iteration 0 / 1000: loss 77.420799
# iteration 100 / 1000: loss 75.932582
# iteration 200 / 1000: loss 74.474985
# iteration 300 / 1000: loss 73.045998
# iteration 400 / 1000: loss 71.645150
# iteration 500 / 1000: loss 70.272280
# iteration 600 / 1000: loss 68.925856
# iteration 700 / 1000: loss 67.607172
# iteration 800 / 1000: loss 66.312119
# iteration 900 / 1000: loss 65.045623
# iteration 0 / 1000: loss 678.654621
# iteration 100 / 1000: loss 555.997717
# iteration 200 / 1000: loss 455.583505
# iteration 300 / 1000: loss 373.381099
# iteration 400 / 1000: loss 306.085966
# iteration 500 / 1000: loss 250.994448
# iteration 600 / 1000: loss 205.894254
# iteration 700 / 1000: loss 168.972122
# iteration 800 / 1000: loss 138.745989
# iteration 900 / 1000: loss 114.002247
# iteration 0 / 1000: loss 7561.485244
# iteration 100 / 1000: loss 1015.079030
# iteration 200 / 1000: loss 137.993948
# iteration 300 / 1000: loss 20.482488
# iteration 400 / 1000: loss 4.738332
# iteration 500 / 1000: loss 2.628918
# iteration 600 / 1000: loss 2.346310
# iteration 700 / 1000: loss 2.308442
# iteration 800 / 1000: loss 2.303370
# iteration 900 / 1000: loss 2.302690
# iteration 0 / 1000: loss 76.595074
# iteration 100 / 1000: loss 63.121774
# iteration 200 / 1000: loss 52.092749
# iteration 300 / 1000: loss 43.063090
# iteration 400 / 1000: loss 35.672085
# iteration 500 / 1000: loss 29.619028
# iteration 600 / 1000: loss 24.665640
# iteration 700 / 1000: loss 20.609781
# iteration 800 / 1000: loss 17.289632
# iteration 900 / 1000: loss 14.572133
# iteration 0 / 1000: loss 765.445001
# iteration 100 / 1000: loss 104.548242
# iteration 200 / 1000: loss 16.001543
# iteration 300 / 1000: loss 4.137971
# iteration 400 / 1000: loss 2.548482
# iteration 500 / 1000: loss 2.335527
# iteration 600 / 1000: loss 2.306999
# iteration 700 / 1000: loss 2.303176
# iteration 800 / 1000: loss 2.302664
# iteration 900 / 1000: loss 2.302595
# iteration 0 / 1000: loss 7620.845238
# iteration 100 / 1000: loss 2.302590
# iteration 200 / 1000: loss 2.302585
# iteration 300 / 1000: loss 2.302585
# iteration 400 / 1000: loss 2.302585
# iteration 500 / 1000: loss 2.302585
# iteration 600 / 1000: loss 2.302585
# iteration 700 / 1000: loss 2.302585
# iteration 800 / 1000: loss 2.302585
# iteration 900 / 1000: loss 2.302585
# iteration 0 / 1000: loss 79.644204
# iteration 100 / 1000: loss 12.664964
# iteration 200 / 1000: loss 3.690846
# iteration 300 / 1000: loss 2.488616
# iteration 400 / 1000: loss 2.327508
# iteration 500 / 1000: loss 2.305922
# iteration 600 / 1000: loss 2.303031
# iteration 700 / 1000: loss 2.302641
# iteration 800 / 1000: loss 2.302590
# iteration 900 / 1000: loss 2.302583
# iteration 0 / 1000: loss 761.126370
# iteration 100 / 1000: loss 2.302585
# iteration 200 / 1000: loss 2.302585
# iteration 300 / 1000: loss 2.302585
# iteration 400 / 1000: loss 2.302585
# iteration 500 / 1000: loss 2.302585
# iteration 600 / 1000: loss 2.302585
# iteration 700 / 1000: loss 2.302585
# iteration 800 / 1000: loss 2.302585
# iteration 900 / 1000: loss 2.302585
# iteration 0 / 1000: loss 7629.819771
# iteration 100 / 1000: loss 2.302585
# iteration 200 / 1000: loss 2.302585
# iteration 300 / 1000: loss 2.302585
# iteration 400 / 1000: loss 2.302585
# iteration 500 / 1000: loss 2.302585
# iteration 600 / 1000: loss 2.302585
# iteration 700 / 1000: loss 2.302585
# iteration 800 / 1000: loss 2.302585
# iteration 900 / 1000: loss 2.302585
# Done extracting features for 1000 / 49000 images
# Done extracting features for 2000 / 49000 images
# Done extracting features for 3000 / 49000 images
# Done extracting features for 4000 / 49000 images
# Done extracting features for 5000 / 49000 images
# Done extracting features for 6000 / 49000 images
# Done extracting features for 7000 / 49000 images
# Done extracting features for 8000 / 49000 images
# Done extracting features for 9000 / 49000 images
# Done extracting features for 10000 / 49000 images
# Done extracting features for 11000 / 49000 images
# Done extracting features for 12000 / 49000 images
# Done extracting features for 13000 / 49000 images
# Done extracting features for 14000 / 49000 images
# Done extracting features for 15000 / 49000 images
# Done extracting features for 16000 / 49000 images
# Done extracting features for 17000 / 49000 images
# Done extracting features for 18000 / 49000 images
# Done extracting features for 19000 / 49000 images
# Done extracting features for 20000 / 49000 images
# Done extracting features for 21000 / 49000 images
# Done extracting features for 22000 / 49000 images
# Done extracting features for 23000 / 49000 images
# Done extracting features for 24000 / 49000 images
# Done extracting features for 25000 / 49000 images
# Done extracting features for 26000 / 49000 images
# Done extracting features for 27000 / 49000 images
# Done extracting features for 28000 / 49000 images
# Done extracting features for 29000 / 49000 images
# Done extracting features for 30000 / 49000 images
# Done extracting features for 31000 / 49000 images
# Done extracting features for 32000 / 49000 images
# Done extracting features for 33000 / 49000 images
# Done extracting features for 34000 / 49000 images
# Done extracting features for 35000 / 49000 images
# Done extracting features for 36000 / 49000 images
# Done extracting features for 37000 / 49000 images
# Done extracting features for 38000 / 49000 images
# Done extracting features for 39000 / 49000 images
# Done extracting features for 40000 / 49000 images
# Done extracting features for 41000 / 49000 images
# Done extracting features for 42000 / 49000 images
# Done extracting features for 43000 / 49000 images
# Done extracting features for 44000 / 49000 images
# Done extracting features for 45000 / 49000 images
# Done extracting features for 46000 / 49000 images
# Done extracting features for 47000 / 49000 images
# Done extracting features for 48000 / 49000 images
# iteration 0 / 1000: loss 76.240101
# iteration 100 / 1000: loss 74.776427
# iteration 200 / 1000: loss 73.340088
# iteration 300 / 1000: loss 71.934592
# iteration 400 / 1000: loss 70.554545
# iteration 500 / 1000: loss 69.203621
# iteration 600 / 1000: loss 67.878647
# iteration 700 / 1000: loss 66.578865
# iteration 800 / 1000: loss 65.307128
# iteration 900 / 1000: loss 64.058614
# iteration 0 / 1000: loss 776.770750
# iteration 100 / 1000: loss 636.321098
# iteration 200 / 1000: loss 521.340987
# iteration 300 / 1000: loss 427.212399
# iteration 400 / 1000: loss 350.154391
# iteration 500 / 1000: loss 287.070862
# iteration 600 / 1000: loss 235.427523
# iteration 700 / 1000: loss 193.150376
# iteration 800 / 1000: loss 158.539465
# iteration 900 / 1000: loss 130.206622
# iteration 0 / 1000: loss 7893.290495
# iteration 100 / 1000: loss 1059.534632
# iteration 200 / 1000: loss 143.950334
# iteration 300 / 1000: loss 21.280446
# iteration 400 / 1000: loss 4.845227
# iteration 500 / 1000: loss 2.643249
# iteration 600 / 1000: loss 2.348225
# iteration 700 / 1000: loss 2.308700
# iteration 800 / 1000: loss 2.303405
# iteration 900 / 1000: loss 2.302695
# iteration 0 / 1000: loss 85.415207
# iteration 100 / 1000: loss 70.342082
# iteration 200 / 1000: loss 58.003855
# iteration 300 / 1000: loss 47.903431
# iteration 400 / 1000: loss 39.632125
# iteration 500 / 1000: loss 32.862605
# iteration 600 / 1000: loss 27.321111
# iteration 700 / 1000: loss 22.783689
# iteration 800 / 1000: loss 19.069040
# iteration 900 / 1000: loss 16.028530
# iteration 0 / 1000: loss 746.698353
# iteration 100 / 1000: loss 102.035977
# iteration 200 / 1000: loss 15.664882
# iteration 300 / 1000: loss 4.092888
# iteration 400 / 1000: loss 2.542445
# iteration 500 / 1000: loss 2.334725
# iteration 600 / 1000: loss 2.306888
# iteration 700 / 1000: loss 2.303161
# iteration 800 / 1000: loss 2.302662
# iteration 900 / 1000: loss 2.302595
# iteration 0 / 1000: loss 7836.321844
# iteration 100 / 1000: loss 2.302591
# iteration 200 / 1000: loss 2.302585
# iteration 300 / 1000: loss 2.302585
# iteration 400 / 1000: loss 2.302585
# iteration 500 / 1000: loss 2.302585
# iteration 600 / 1000: loss 2.302585
# iteration 700 / 1000: loss 2.302585
# iteration 800 / 1000: loss 2.302585
# iteration 900 / 1000: loss 2.302585
# iteration 0 / 1000: loss 77.163956
# iteration 100 / 1000: loss 12.332156
# iteration 200 / 1000: loss 3.646399
# iteration 300 / 1000: loss 2.482558
# iteration 400 / 1000: loss 2.326704
# iteration 500 / 1000: loss 2.305813
# iteration 600 / 1000: loss 2.303013
# iteration 700 / 1000: loss 2.302640
# iteration 800 / 1000: loss 2.302589
# iteration 900 / 1000: loss 2.302582
# iteration 0 / 1000: loss 844.426550
# iteration 100 / 1000: loss 2.302585
# iteration 200 / 1000: loss 2.302585
# iteration 300 / 1000: loss 2.302585
# iteration 400 / 1000: loss 2.302585
# iteration 500 / 1000: loss 2.302585
# iteration 600 / 1000: loss 2.302585
# iteration 700 / 1000: loss 2.302585
# iteration 800 / 1000: loss 2.302585
# iteration 900 / 1000: loss 2.302585
# iteration 0 / 1000: loss 7918.212573
# iteration 100 / 1000: loss 2.302585
# iteration 200 / 1000: loss 2.302585
# iteration 300 / 1000: loss 2.302585
# iteration 400 / 1000: loss 2.302585
# iteration 500 / 1000: loss 2.302585
# iteration 600 / 1000: loss 2.302585
# iteration 700 / 1000: loss 2.302585
# iteration 800 / 1000: loss 2.302585
# iteration 900 / 1000: loss 2.302585
# Done extracting features for 1000 / 49000 images
# Done extracting features for 2000 / 49000 images
# Done extracting features for 3000 / 49000 images
# Done extracting features for 4000 / 49000 images
# Done extracting features for 5000 / 49000 images
# Done extracting features for 6000 / 49000 images
# Done extracting features for 7000 / 49000 images
# Done extracting features for 8000 / 49000 images
# Done extracting features for 9000 / 49000 images
# Done extracting features for 10000 / 49000 images
# Done extracting features for 11000 / 49000 images
# Done extracting features for 12000 / 49000 images
# Done extracting features for 13000 / 49000 images
# Done extracting features for 14000 / 49000 images
# Done extracting features for 15000 / 49000 images
# Done extracting features for 16000 / 49000 images
# Done extracting features for 17000 / 49000 images
# Done extracting features for 18000 / 49000 images
# Done extracting features for 19000 / 49000 images
# Done extracting features for 20000 / 49000 images
# Done extracting features for 21000 / 49000 images
# Done extracting features for 22000 / 49000 images
# Done extracting features for 23000 / 49000 images
# Done extracting features for 24000 / 49000 images
# Done extracting features for 25000 / 49000 images
# Done extracting features for 26000 / 49000 images
# Done extracting features for 27000 / 49000 images
# Done extracting features for 28000 / 49000 images
# Done extracting features for 29000 / 49000 images
# Done extracting features for 30000 / 49000 images
# Done extracting features for 31000 / 49000 images
# Done extracting features for 32000 / 49000 images
# Done extracting features for 33000 / 49000 images
# Done extracting features for 34000 / 49000 images
# Done extracting features for 35000 / 49000 images
# Done extracting features for 36000 / 49000 images
# Done extracting features for 37000 / 49000 images
# Done extracting features for 38000 / 49000 images
# Done extracting features for 39000 / 49000 images
# Done extracting features for 40000 / 49000 images
# Done extracting features for 41000 / 49000 images
# Done extracting features for 42000 / 49000 images
# Done extracting features for 43000 / 49000 images
# Done extracting features for 44000 / 49000 images
# Done extracting features for 45000 / 49000 images
# Done extracting features for 46000 / 49000 images
# Done extracting features for 47000 / 49000 images
# Done extracting features for 48000 / 49000 images
# iteration 0 / 1000: loss 80.024536
# iteration 100 / 1000: loss 78.485742
# iteration 200 / 1000: loss 76.977301
# iteration 300 / 1000: loss 75.497453
# iteration 400 / 1000: loss 74.047849
# iteration 500 / 1000: loss 72.627521
# iteration 600 / 1000: loss 71.235654
# iteration 700 / 1000: loss 69.870187
# iteration 800 / 1000: loss 68.531436
# iteration 900 / 1000: loss 67.223345
# iteration 0 / 1000: loss 802.518824
# iteration 100 / 1000: loss 657.397884
# iteration 200 / 1000: loss 538.595286
# iteration 300 / 1000: loss 441.338068
# iteration 400 / 1000: loss 361.718874
# iteration 500 / 1000: loss 296.538968
# iteration 600 / 1000: loss 243.178535
# iteration 700 / 1000: loss 199.495937
# iteration 800 / 1000: loss 163.733738
# iteration 900 / 1000: loss 134.458812
# iteration 0 / 1000: loss 7871.589545
# iteration 100 / 1000: loss 1056.626986
# iteration 200 / 1000: loss 143.560707
# iteration 300 / 1000: loss 21.228292
# iteration 400 / 1000: loss 4.838264
# iteration 500 / 1000: loss 2.642315
# iteration 600 / 1000: loss 2.348099
# iteration 700 / 1000: loss 2.308684
# iteration 800 / 1000: loss 2.303402
# iteration 900 / 1000: loss 2.302695
# iteration 0 / 1000: loss 83.417368
# iteration 100 / 1000: loss 68.707883
# iteration 200 / 1000: loss 56.664088
# iteration 300 / 1000: loss 46.805570
# iteration 400 / 1000: loss 38.734833
# iteration 500 / 1000: loss 32.127907
# iteration 600 / 1000: loss 26.719139
# iteration 700 / 1000: loss 22.291351
# iteration 800 / 1000: loss 18.666551
# iteration 900 / 1000: loss 15.698781
# iteration 0 / 1000: loss 833.767908
# iteration 100 / 1000: loss 113.701861
# iteration 200 / 1000: loss 17.227729
# iteration 300 / 1000: loss 4.302226
# iteration 400 / 1000: loss 2.570504
# iteration 500 / 1000: loss 2.338475
# iteration 600 / 1000: loss 2.307394
# iteration 700 / 1000: loss 2.303230
# iteration 800 / 1000: loss 2.302671
# iteration 900 / 1000: loss 2.302596
# iteration 0 / 1000: loss 8099.051209
# iteration 100 / 1000: loss 2.302591
# iteration 200 / 1000: loss 2.302585
# iteration 300 / 1000: loss 2.302585
# iteration 400 / 1000: loss 2.302585
# iteration 500 / 1000: loss 2.302585
# iteration 600 / 1000: loss 2.302585
# iteration 700 / 1000: loss 2.302585
# iteration 800 / 1000: loss 2.302585
# iteration 900 / 1000: loss 2.302585
# iteration 0 / 1000: loss 76.611791
# iteration 100 / 1000: loss 12.258401
# iteration 200 / 1000: loss 3.636256
# iteration 300 / 1000: loss 2.481291
# iteration 400 / 1000: loss 2.326509
# iteration 500 / 1000: loss 2.305790
# iteration 600 / 1000: loss 2.303011
# iteration 700 / 1000: loss 2.302638
# iteration 800 / 1000: loss 2.302589
# iteration 900 / 1000: loss 2.302583
# iteration 0 / 1000: loss 780.103821
# iteration 100 / 1000: loss 2.302585
# iteration 200 / 1000: loss 2.302585
# iteration 300 / 1000: loss 2.302585
# iteration 400 / 1000: loss 2.302585
# iteration 500 / 1000: loss 2.302585
# iteration 600 / 1000: loss 2.302585
# iteration 700 / 1000: loss 2.302585
# iteration 800 / 1000: loss 2.302585
# iteration 900 / 1000: loss 2.302585
# iteration 0 / 1000: loss 8085.163823
# iteration 100 / 1000: loss 2.302585
# iteration 200 / 1000: loss 2.302585
# iteration 300 / 1000: loss 2.302585
# iteration 400 / 1000: loss 2.302585
# iteration 500 / 1000: loss 2.302585
# iteration 600 / 1000: loss 2.302585
# iteration 700 / 1000: loss 2.302585
# iteration 800 / 1000: loss 2.302585
# iteration 900 / 1000: loss 2.302585
# best number of bins: 15
# lr 1.000000e-09 reg 1.000000e+05 train accuracy: 0.094939 val accuracy: 0.088000
# lr 1.000000e-09 reg 1.000000e+06 train accuracy: 0.104000 val accuracy: 0.109000
# lr 1.000000e-09 reg 1.000000e+07 train accuracy: 0.122490 val accuracy: 0.107000
# lr 1.000000e-08 reg 1.000000e+05 train accuracy: 0.106306 val accuracy: 0.114000
# lr 1.000000e-08 reg 1.000000e+06 train accuracy: 0.305184 val accuracy: 0.286000
# lr 1.000000e-08 reg 1.000000e+07 train accuracy: 0.414857 val accuracy: 0.417000
# lr 1.000000e-07 reg 1.000000e+05 train accuracy: 0.413673 val accuracy: 0.418000
# lr 1.000000e-07 reg 1.000000e+06 train accuracy: 0.420653 val accuracy: 0.430000
# lr 1.000000e-07 reg 1.000000e+07 train accuracy: 0.319449 val accuracy: 0.332000
# best validation accuracy achieved during cross-validation: 0.430000

# %%
# Evaluate your trained Softmax on the test set
y_test_pred = best_softmax.predict(X_test_feats)
test_accuracy = np.mean(y_test == y_test_pred)
print test_accuracy
# Out:
# 0.427

# %%
# An important way to gain intuition about how an algorithm works is to
# visualize the mistakes that it makes. In this visualization, we show examples
# of images that are misclassified by our current system. The first column
# shows images that our system labeled as "plane" but whose true label is
# something other than "plane".

examples_per_class = 8
classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for cls, cls_name in enumerate(classes):
    idxs = np.where((y_test != cls) & (y_test_pred == cls))[0]
    idxs = np.random.choice(idxs, examples_per_class, replace=False)
    for i, idx in enumerate(idxs):
        plt.subplot(examples_per_class, len(classes), i * len(classes) + cls + 1)
        plt.imshow(X_test[idx].astype('uint8'))
        plt.axis('off')
        if i == 0:
            plt.title(cls_name)
plt.show()

# %% [markdown]
# ### Inline question 1:
# Describe the misclassification results that you see. Do they make sense?
#
# The columns corresponding to plane and ship have backgrounds that could be confused with skies and water, respectively, making some sense of the misclassification results. In a similar manner, some cats and frog images shown look alike, making sense of this confusion. Besides, there are some images (like the ones in the dog column) in which the shape suggests similarities with the misclassified class.

# %% [markdown]
# ## Neural Network on image features
# Earlier in this assigment we saw that training a two-layer neural network on raw pixels achieved better classification performance than linear classifiers on raw pixels. In this notebook we have seen that linear classifiers on image features outperform linear classifiers on raw pixels.
#
# For completeness, we should also try training a neural network on image features. This approach should outperform all previous approaches: you should easily be able to achieve over 55% classification accuracy on the test set; our best model achieves about 60% classification accuracy.

# %%
print X_train_feats.shape
# Out:
# (49000, 160)

# %%
from cs231n.classifiers.neural_net import TwoLayerNet

input_dim = X_train_feats.shape[1]
hidden_dim = 500
num_classes = 10

net = TwoLayerNet(input_dim, hidden_dim, num_classes)
best_net = None

################################################################################
# TODO: Train a two-layer neural network on image features. You may want to    #
# cross-validate various parameters as in previous sections. Store your best   #
# model in the best_net variable.                                              #
################################################################################
best_acc = 0
best_combination = None
best_stats = None

tries = 20

for combination in zip(np.random.randint(100, 350, size=tries),
                       10 ** np.random.uniform(-0.5, 0.5, size=tries),
                       np.random.randint(2000, 2500, size=tries),
                       10 ** np.random.uniform(-4, -2, size=tries)):
    print(combination)
    hidden_size, learning_rate, num_iters, reg = combination#(333, 0.96560010479998937, 1200, 0.0050740053375667486)#combination
    
    net = TwoLayerNet(input_dim, hidden_size, num_classes)

    # Train the network
    stats = net.train(X_train_feats, y_train, X_val_feats, y_val,
                      num_iters=num_iters, batch_size=200,
                      learning_rate=learning_rate, learning_rate_decay=0.95,
                      reg=reg, verbose=True)

    # Predict on the validation set
    val_acc = (net.predict(X_val_feats) == y_val).mean()
    print 'Validation accuracy: ', val_acc

    if val_acc > best_acc:
        best_acc = val_acc
        best_net = net
        best_combination = combination
        best_stats = stats

        
# Plot the loss function and train / validation accuracies
plt.subplot(2, 1, 1)
plt.plot(best_stats['loss_history'])
plt.title('Loss history')
plt.xlabel('Iteration')
plt.ylabel('Loss')

plt.subplot(2, 1, 2)
plt.plot(best_stats['train_acc_history'], label='train')
plt.plot(best_stats['val_acc_history'], label='val')
plt.title('Classification accuracy history')
plt.xlabel('Epoch')
plt.ylabel('Clasification accuracy')
plt.show()
################################################################################
#                              END OF YOUR CODE                                #
################################################################################
# Out:
# (228, 2.3871669570466039, 2344, 0.0012795272940572344)
# iteration 0 / 2344: loss 2.302585
# iteration 100 / 2344: loss 1.715953
# iteration 200 / 2344: loss 1.600782
# iteration 300 / 2344: loss 1.594730
# iteration 400 / 2344: loss 1.500976
# iteration 500 / 2344: loss 1.410674
# iteration 600 / 2344: loss 1.514876
# iteration 700 / 2344: loss 1.466115
# iteration 800 / 2344: loss 1.462362
# iteration 900 / 2344: loss 1.430903
# iteration 1000 / 2344: loss 1.433487
# iteration 1100 / 2344: loss 1.464152
# iteration 1200 / 2344: loss 1.496799
# iteration 1300 / 2344: loss 1.444858
# iteration 1400 / 2344: loss 1.387149
# iteration 1500 / 2344: loss 1.182604
# iteration 1600 / 2344: loss 1.499287
# iteration 1700 / 2344: loss 1.192786
# iteration 1800 / 2344: loss 1.289937
# iteration 1900 / 2344: loss 1.343735
# iteration 2000 / 2344: loss 1.283545
# iteration 2100 / 2344: loss 1.271792
# iteration 2200 / 2344: loss 1.223262
# iteration 2300 / 2344: loss 1.338106
# Validation accuracy:  0.53
# (107, 2.5358872594098361, 2249, 0.00026907418165455837)
# iteration 0 / 2249: loss 2.302585
# iteration 100 / 2249: loss 1.437713
# iteration 200 / 2249: loss 1.573250
# iteration 300 / 2249: loss 1.403813
# iteration 400 / 2249: loss 1.395871
# iteration 500 / 2249: loss 1.407126
# iteration 600 / 2249: loss 1.389375
# iteration 700 / 2249: loss 1.366177
# iteration 800 / 2249: loss 1.516680
# iteration 900 / 2249: loss 1.364626
# iteration 1000 / 2249: loss 1.153058
# iteration 1100 / 2249: loss 1.240382
# iteration 1200 / 2249: loss 1.334680
# iteration 1300 / 2249: loss 1.207654
# iteration 1400 / 2249: loss 1.270094
# iteration 1500 / 2249: loss 1.435653
# iteration 1600 / 2249: loss 1.189936
# iteration 1700 / 2249: loss 1.241538
# iteration 1800 / 2249: loss 1.176465
# iteration 1900 / 2249: loss 1.044352
# iteration 2000 / 2249: loss 1.329447
# iteration 2100 / 2249: loss 1.212077
# iteration 2200 / 2249: loss 1.294823
# Validation accuracy:  0.548
# (281, 0.50952697186921259, 2052, 0.00020853268488226227)
# iteration 0 / 2052: loss 2.302585
# iteration 100 / 2052: loss 1.482679
# iteration 200 / 2052: loss 1.345881
# iteration 300 / 2052: loss 1.314307
# iteration 400 / 2052: loss 1.222717
# iteration 500 / 2052: loss 1.091401
# iteration 600 / 2052: loss 1.139978
# iteration 700 / 2052: loss 0.987803
# iteration 800 / 2052: loss 1.085815
# iteration 900 / 2052: loss 1.225784
# iteration 1000 / 2052: loss 1.018927
# iteration 1100 / 2052: loss 1.238421
# iteration 1200 / 2052: loss 1.128019
# iteration 1300 / 2052: loss 0.911503
# iteration 1400 / 2052: loss 0.849634
# iteration 1500 / 2052: loss 0.941167
# iteration 1600 / 2052: loss 1.002159
# iteration 1700 / 2052: loss 0.907199
# iteration 1800 / 2052: loss 0.904268
# iteration 1900 / 2052: loss 0.948980
# iteration 2000 / 2052: loss 0.887776
# Validation accuracy:  0.591
# (107, 1.8674969405236899, 2417, 0.00018798047023571359)
# iteration 0 / 2417: loss 2.302585
# iteration 100 / 2417: loss 1.376779
# iteration 200 / 2417: loss 1.449631
# iteration 300 / 2417: loss 1.208342
# iteration 400 / 2417: loss 1.286322
# iteration 500 / 2417: loss 1.235012
# iteration 600 / 2417: loss 1.320626
# iteration 700 / 2417: loss 1.276081
# iteration 800 / 2417: loss 1.305954
# iteration 900 / 2417: loss 1.365568
# iteration 1000 / 2417: loss 1.120490
# iteration 1100 / 2417: loss 1.248534
# iteration 1200 / 2417: loss 1.257459
# iteration 1300 / 2417: loss 1.116255
# iteration 1400 / 2417: loss 1.128906
# iteration 1500 / 2417: loss 1.235572
# iteration 1600 / 2417: loss 1.246845
# iteration 1700 / 2417: loss 1.043878
# iteration 1800 / 2417: loss 1.312434
# iteration 1900 / 2417: loss 1.176392
# iteration 2000 / 2417: loss 1.086231
# iteration 2100 / 2417: loss 1.101673
# iteration 2200 / 2417: loss 0.996271
# iteration 2300 / 2417: loss 1.077767
# iteration 2400 / 2417: loss 1.150596
# Validation accuracy:  0.548
# (133, 1.6463396170795468, 2270, 0.0071482005495916148)
# iteration 0 / 2270: loss 2.302586
# iteration 100 / 2270: loss 1.629979
# iteration 200 / 2270: loss 1.669904
# iteration 300 / 2270: loss 1.559099
# iteration 400 / 2270: loss 1.535775
# iteration 500 / 2270: loss 1.795148
# iteration 600 / 2270: loss 1.701772
# iteration 700 / 2270: loss 1.689162
# iteration 800 / 2270: loss 1.634404
# iteration 900 / 2270: loss 1.567726
# iteration 1000 / 2270: loss 1.602983
# iteration 1100 / 2270: loss 1.569628
# iteration 1200 / 2270: loss 1.475057
# iteration 1300 / 2270: loss 1.532587
# iteration 1400 / 2270: loss 1.657675
# iteration 1500 / 2270: loss 1.518134
# iteration 1600 / 2270: loss 1.613421
# iteration 1700 / 2270: loss 1.520320
# iteration 1800 / 2270: loss 1.410541
# iteration 1900 / 2270: loss 1.490582
# iteration 2000 / 2270: loss 1.509903
# iteration 2100 / 2270: loss 1.539320
# iteration 2200 / 2270: loss 1.420327
# Validation accuracy:  0.52
# (118, 1.1995848615942288, 2485, 0.0001160313388928167)
# iteration 0 / 2485: loss 2.302585
# iteration 100 / 2485: loss 1.443646
# iteration 200 / 2485: loss 1.334651
# iteration 300 / 2485: loss 1.364899
# iteration 400 / 2485: loss 1.309722
# iteration 500 / 2485: loss 1.221106
# iteration 600 / 2485: loss 1.166656
# iteration 700 / 2485: loss 1.151881
# iteration 800 / 2485: loss 1.125809
# iteration 900 / 2485: loss 1.121469
# iteration 1000 / 2485: loss 1.066979
# iteration 1100 / 2485: loss 1.209703
# iteration 1200 / 2485: loss 1.146370
# iteration 1300 / 2485: loss 1.009329
# iteration 1400 / 2485: loss 0.913507
# iteration 1500 / 2485: loss 1.034094
# iteration 1600 / 2485: loss 0.897334
# iteration 1700 / 2485: loss 1.001111
# iteration 1800 / 2485: loss 0.936699
# iteration 1900 / 2485: loss 1.027944
# iteration 2000 / 2485: loss 0.945937
# iteration 2100 / 2485: loss 0.953459
# iteration 2200 / 2485: loss 0.900594
# iteration 2300 / 2485: loss 0.934763
# iteration 2400 / 2485: loss 1.009375
# Validation accuracy:  0.579
# (307, 0.86762132070545939, 2081, 0.00015083058386618515)
# iteration 0 / 2081: loss 2.302585
# iteration 100 / 2081: loss 1.461411
# iteration 200 / 2081: loss 1.440253
# iteration 300 / 2081: loss 1.176556
# iteration 400 / 2081: loss 1.150637
# iteration 500 / 2081: loss 1.133070
# iteration 600 / 2081: loss 1.247051
# iteration 700 / 2081: loss 1.111612
# iteration 800 / 2081: loss 1.013867
# iteration 900 / 2081: loss 1.067426
# iteration 1000 / 2081: loss 0.893077
# iteration 1100 / 2081: loss 1.092203
# iteration 1200 / 2081: loss 1.003100
# iteration 1300 / 2081: loss 0.994702
# iteration 1400 / 2081: loss 0.915149
# iteration 1500 / 2081: loss 0.876713
# iteration 1600 / 2081: loss 0.870471
# iteration 1700 / 2081: loss 0.736784
# iteration 1800 / 2081: loss 0.795516
# iteration 1900 / 2081: loss 0.835722
# iteration 2000 / 2081: loss 0.884580
# Validation accuracy:  0.576
# (194, 1.3176707683929212, 2142, 0.0014248331855117912)
# iteration 0 / 2142: loss 2.302585
# iteration 100 / 2142: loss 1.390783
# iteration 200 / 2142: loss 1.426134
# iteration 300 / 2142: loss 1.305201
# iteration 400 / 2142: loss 1.290469
# iteration 500 / 2142: loss 1.351582
# iteration 600 / 2142: loss 1.280309
# iteration 700 / 2142: loss 1.247893
# iteration 800 / 2142: loss 1.055961
# iteration 900 / 2142: loss 1.307072
# iteration 1000 / 2142: loss 1.224441
# iteration 1100 / 2142: loss 1.231009
# iteration 1200 / 2142: loss 1.178935
# iteration 1300 / 2142: loss 1.346147
# iteration 1400 / 2142: loss 1.283555
# iteration 1500 / 2142: loss 1.261464
# iteration 1600 / 2142: loss 1.216011
# iteration 1700 / 2142: loss 1.360675
# iteration 1800 / 2142: loss 1.221351
# iteration 1900 / 2142: loss 1.038612
# iteration 2000 / 2142: loss 1.166247
# iteration 2100 / 2142: loss 1.176506
# Validation accuracy:  0.543
# (243, 0.64143686114555909, 2332, 0.0080962464278862452)
# iteration 0 / 2332: loss 2.302587
# iteration 100 / 2332: loss 1.624365
# iteration 200 / 2332: loss 1.497106
# iteration 300 / 2332: loss 1.425954
# iteration 400 / 2332: loss 1.527375
# iteration 500 / 2332: loss 1.377927
# iteration 600 / 2332: loss 1.513961
# iteration 700 / 2332: loss 1.351152
# iteration 800 / 2332: loss 1.345878
# iteration 900 / 2332: loss 1.290779
# iteration 1000 / 2332: loss 1.377844
# iteration 1100 / 2332: loss 1.451499
# iteration 1200 / 2332: loss 1.307556
# iteration 1300 / 2332: loss 1.303415
# iteration 1400 / 2332: loss 1.294540
# iteration 1500 / 2332: loss 1.487620
# iteration 1600 / 2332: loss 1.408953
# iteration 1700 / 2332: loss 1.421186
# iteration 1800 / 2332: loss 1.409737
# iteration 1900 / 2332: loss 1.441957
# iteration 2000 / 2332: loss 1.336395
# iteration 2100 / 2332: loss 1.281842
# iteration 2200 / 2332: loss 1.398680
# iteration 2300 / 2332: loss 1.451488
# Validation accuracy:  0.552
# (144, 0.83706315927797714, 2355, 0.00022474341637415189)
# iteration 0 / 2355: loss 2.302585
# iteration 100 / 2355: loss 1.368386
# iteration 200 / 2355: loss 1.553245
# iteration 300 / 2355: loss 1.119972
# iteration 400 / 2355: loss 1.356576
# iteration 500 / 2355: loss 1.159722
# iteration 600 / 2355: loss 1.190064
# iteration 700 / 2355: loss 1.142941
# iteration 800 / 2355: loss 0.999970
# iteration 900 / 2355: loss 1.161529
# iteration 1000 / 2355: loss 1.022293
# iteration 1100 / 2355: loss 1.071017
# iteration 1200 / 2355: loss 0.894106
# iteration 1300 / 2355: loss 0.966554
# iteration 1400 / 2355: loss 1.036905
# iteration 1500 / 2355: loss 1.129657
# iteration 1600 / 2355: loss 0.976590
# iteration 1700 / 2355: loss 0.980725
# iteration 1800 / 2355: loss 1.220084
# iteration 1900 / 2355: loss 0.970236
# iteration 2000 / 2355: loss 0.998977
# iteration 2100 / 2355: loss 1.005866
# iteration 2200 / 2355: loss 1.039620
# iteration 2300 / 2355: loss 0.892954
# Validation accuracy:  0.577
# (101, 1.2531340065725762, 2109, 0.0043635995073659332)
# iteration 0 / 2109: loss 2.302585
# iteration 100 / 2109: loss 1.563233
# iteration 200 / 2109: loss 1.466954
# iteration 300 / 2109: loss 1.471148
# iteration 400 / 2109: loss 1.394084
# iteration 500 / 2109: loss 1.638368
# iteration 600 / 2109: loss 1.369554
# iteration 700 / 2109: loss 1.457256
# iteration 800 / 2109: loss 1.320393
# iteration 900 / 2109: loss 1.311322
# iteration 1000 / 2109: loss 1.508951
# iteration 1100 / 2109: loss 1.263290
# iteration 1200 / 2109: loss 1.302514
# iteration 1300 / 2109: loss 1.620333
# iteration 1400 / 2109: loss 1.433241
# iteration 1500 / 2109: loss 1.471603
# iteration 1600 / 2109: loss 1.394053
# iteration 1700 / 2109: loss 1.463740
# iteration 1800 / 2109: loss 1.433569
# iteration 1900 / 2109: loss 1.421084
# iteration 2000 / 2109: loss 1.339887
# iteration 2100 / 2109: loss 1.394877
# Validation accuracy:  0.545
# (236, 1.2257242840249001, 2027, 0.00018810645761804446)
# iteration 0 / 2027: loss 2.302585
# iteration 100 / 2027: loss 1.377141
# iteration 200 / 2027: loss 1.341017
# iteration 300 / 2027: loss 1.263338
# iteration 400 / 2027: loss 1.234299
# iteration 500 / 2027: loss 1.303336
# iteration 600 / 2027: loss 1.008529
# iteration 700 / 2027: loss 1.187834
# iteration 800 / 2027: loss 0.992657
# iteration 900 / 2027: loss 1.094875
# iteration 1000 / 2027: loss 1.156971
# iteration 1100 / 2027: loss 1.022074
# iteration 1200 / 2027: loss 0.895530
# iteration 1300 / 2027: loss 1.007357
# iteration 1400 / 2027: loss 1.072081
# iteration 1500 / 2027: loss 0.898709
# iteration 1600 / 2027: loss 0.907870
# iteration 1700 / 2027: loss 0.978619
# iteration 1800 / 2027: loss 0.980312
# iteration 1900 / 2027: loss 0.941364
# iteration 2000 / 2027: loss 0.852537
# Validation accuracy:  0.566
# (288, 0.66730693180652578, 2323, 0.00020550346148291032)
# iteration 0 / 2323: loss 2.302585
# iteration 100 / 2323: loss 1.577162
# iteration 200 / 2323: loss 1.270023
# iteration 300 / 2323: loss 1.400229
# iteration 400 / 2323: loss 1.113888
# iteration 500 / 2323: loss 1.351931
# iteration 600 / 2323: loss 1.115571
# iteration 700 / 2323: loss 1.085419
# iteration 800 / 2323: loss 1.100562
# iteration 900 / 2323: loss 1.059661
# iteration 1000 / 2323: loss 1.134718
# iteration 1100 / 2323: loss 1.024369
# iteration 1200 / 2323: loss 1.021702
# iteration 1300 / 2323: loss 1.114158
# iteration 1400 / 2323: loss 0.933346
# iteration 1500 / 2323: loss 0.827717
# iteration 1600 / 2323: loss 0.862819
# iteration 1700 / 2323: loss 0.906171
# iteration 1800 / 2323: loss 0.898501
# iteration 1900 / 2323: loss 1.016527
# iteration 2000 / 2323: loss 0.780565
# iteration 2100 / 2323: loss 1.032910
# iteration 2200 / 2323: loss 0.831353
# iteration 2300 / 2323: loss 0.793392
# Validation accuracy:  0.58
# (228, 0.44021138223898043, 2043, 0.0010663940180190483)
# iteration 0 / 2043: loss 2.302585
# iteration 100 / 2043: loss 1.538021
# iteration 200 / 2043: loss 1.409023
# iteration 300 / 2043: loss 1.468114
# iteration 400 / 2043: loss 1.322652
# iteration 500 / 2043: loss 1.193424
# iteration 600 / 2043: loss 1.282109
# iteration 700 / 2043: loss 1.252933
# iteration 800 / 2043: loss 1.229509
# iteration 900 / 2043: loss 1.155360
# iteration 1000 / 2043: loss 1.163205
# iteration 1100 / 2043: loss 1.065930
# iteration 1200 / 2043: loss 1.118448
# iteration 1300 / 2043: loss 1.131351
# iteration 1400 / 2043: loss 1.164809
# iteration 1500 / 2043: loss 1.066483
# iteration 1600 / 2043: loss 1.175891
# iteration 1700 / 2043: loss 0.974402
# iteration 1800 / 2043: loss 1.088412
# iteration 1900 / 2043: loss 1.008228
# iteration 2000 / 2043: loss 1.036729
# Validation accuracy:  0.602
# (123, 0.87731023251794327, 2010, 0.0047274177754042931)
# iteration 0 / 2010: loss 2.302586
# iteration 100 / 2010: loss 1.548228
# iteration 200 / 2010: loss 1.466623
# iteration 300 / 2010: loss 1.480788
# iteration 400 / 2010: loss 1.338174
# iteration 500 / 2010: loss 1.515551
# iteration 600 / 2010: loss 1.515493
# iteration 700 / 2010: loss 1.424950
# iteration 800 / 2010: loss 1.515364
# iteration 900 / 2010: loss 1.493612
# iteration 1000 / 2010: loss 1.381003
# iteration 1100 / 2010: loss 1.280418
# iteration 1200 / 2010: loss 1.419833
# iteration 1300 / 2010: loss 1.430346
# iteration 1400 / 2010: loss 1.282280
# iteration 1500 / 2010: loss 1.374674
# iteration 1600 / 2010: loss 1.348017
# iteration 1700 / 2010: loss 1.501066
# iteration 1800 / 2010: loss 1.336948
# iteration 1900 / 2010: loss 1.324911
# iteration 2000 / 2010: loss 1.290748
# Validation accuracy:  0.558
# (181, 0.54812381086267303, 2477, 0.00010500060321656488)
# iteration 0 / 2477: loss 2.302585
# iteration 100 / 2477: loss 1.506744
# iteration 200 / 2477: loss 1.331378
# iteration 300 / 2477: loss 1.344761
# iteration 400 / 2477: loss 1.228923
# iteration 500 / 2477: loss 1.205621
# iteration 600 / 2477: loss 1.234188
# iteration 700 / 2477: loss 1.188824
# iteration 800 / 2477: loss 1.074073
# iteration 900 / 2477: loss 0.949086
# iteration 1000 / 2477: loss 1.104855
# iteration 1100 / 2477: loss 0.936199
# iteration 1200 / 2477: loss 1.163586
# iteration 1300 / 2477: loss 1.061677
# iteration 1400 / 2477: loss 0.991601
# iteration 1500 / 2477: loss 1.042276
# iteration 1600 / 2477: loss 1.055382
# iteration 1700 / 2477: loss 0.970954
# iteration 1800 / 2477: loss 0.810846
# iteration 1900 / 2477: loss 0.857229
# iteration 2000 / 2477: loss 0.783701
# iteration 2100 / 2477: loss 0.942824
# iteration 2200 / 2477: loss 0.913471
# iteration 2300 / 2477: loss 0.719362
# iteration 2400 / 2477: loss 0.821100
# Validation accuracy:  0.576
# (249, 1.476854289562531, 2275, 0.007518345986637337)
# iteration 0 / 2275: loss 2.302587
# iteration 100 / 2275: loss 1.664046
# iteration 200 / 2275: loss 1.465154
# iteration 300 / 2275: loss 1.502890
# iteration 400 / 2275: loss 1.665875
# iteration 500 / 2275: loss 1.464487
# iteration 600 / 2275: loss 1.584710
# iteration 700 / 2275: loss 1.543005
# iteration 800 / 2275: loss 1.433267
# iteration 900 / 2275: loss 1.427199
# iteration 1000 / 2275: loss 1.523832
# iteration 1100 / 2275: loss 1.710815
# iteration 1200 / 2275: loss 1.438480
# iteration 1300 / 2275: loss 1.585986
# iteration 1400 / 2275: loss 1.490829
# iteration 1500 / 2275: loss 1.628294
# iteration 1600 / 2275: loss 1.515264
# iteration 1700 / 2275: loss 1.568710
# iteration 1800 / 2275: loss 1.583984
# iteration 1900 / 2275: loss 1.546955
# iteration 2000 / 2275: loss 1.533490
# iteration 2100 / 2275: loss 1.397961
# iteration 2200 / 2275: loss 1.487798
# Validation accuracy:  0.521
# (296, 1.2720675204097414, 2265, 0.00018804175858307191)
# iteration 0 / 2265: loss 2.302585
# iteration 100 / 2265: loss 1.481703
# iteration 200 / 2265: loss 1.401046
# iteration 300 / 2265: loss 1.281392
# iteration 400 / 2265: loss 1.306703
# iteration 500 / 2265: loss 1.133494
# iteration 600 / 2265: loss 1.072575
# iteration 700 / 2265: loss 1.068558
# iteration 800 / 2265: loss 1.145882
# iteration 900 / 2265: loss 1.099796
# iteration 1000 / 2265: loss 1.121381
# iteration 1100 / 2265: loss 1.054237
# iteration 1200 / 2265: loss 1.075956
# iteration 1300 / 2265: loss 0.745065
# iteration 1400 / 2265: loss 0.859782
# iteration 1500 / 2265: loss 0.922767
# iteration 1600 / 2265: loss 0.849219
# iteration 1700 / 2265: loss 0.842862
# iteration 1800 / 2265: loss 0.777219
# iteration 1900 / 2265: loss 0.781218
# iteration 2000 / 2265: loss 0.757344
# iteration 2100 / 2265: loss 0.837473
# iteration 2200 / 2265: loss 0.839383
# Validation accuracy:  0.54
# (104, 0.40755777002396087, 2417, 0.0013553606543101628)
# iteration 0 / 2417: loss 2.302585
# iteration 100 / 2417: loss 1.656335
# iteration 200 / 2417: loss 1.387610
# iteration 300 / 2417: loss 1.407809
# iteration 400 / 2417: loss 1.282058
# iteration 500 / 2417: loss 1.349749
# iteration 600 / 2417: loss 1.338479
# iteration 700 / 2417: loss 1.276189
# iteration 800 / 2417: loss 1.257883
# iteration 900 / 2417: loss 1.193471
# iteration 1000 / 2417: loss 1.300781
# iteration 1100 / 2417: loss 1.207764
# iteration 1200 / 2417: loss 1.160609
# iteration 1300 / 2417: loss 1.104074
# iteration 1400 / 2417: loss 1.135123
# iteration 1500 / 2417: loss 1.124529
# iteration 1600 / 2417: loss 1.194903
# iteration 1700 / 2417: loss 1.064048
# iteration 1800 / 2417: loss 1.141154
# iteration 1900 / 2417: loss 1.111794
# iteration 2000 / 2417: loss 1.037399
# iteration 2100 / 2417: loss 1.119968
# iteration 2200 / 2417: loss 1.073418
# iteration 2300 / 2417: loss 1.191049
# iteration 2400 / 2417: loss 1.128985
# Validation accuracy:  0.588
# (265, 0.79219821939136059, 2196, 0.0014468788314339397)
# iteration 0 / 2196: loss 2.302586
# iteration 100 / 2196: loss 1.525532
# iteration 200 / 2196: loss 1.368764
# iteration 300 / 2196: loss 1.331125
# iteration 400 / 2196: loss 1.350901
# iteration 500 / 2196: loss 1.226323
# iteration 600 / 2196: loss 1.165707
# iteration 700 / 2196: loss 1.067732
# iteration 800 / 2196: loss 1.275114
# iteration 900 / 2196: loss 1.163194
# iteration 1000 / 2196: loss 1.292649
# iteration 1100 / 2196: loss 1.187310
# iteration 1200 / 2196: loss 1.051438
# iteration 1300 / 2196: loss 1.126699
# iteration 1400 / 2196: loss 1.109667
# iteration 1500 / 2196: loss 1.075421
# iteration 1600 / 2196: loss 1.174131
# iteration 1700 / 2196: loss 1.305485
# iteration 1800 / 2196: loss 1.115093
# iteration 1900 / 2196: loss 1.168447
# iteration 2000 / 2196: loss 0.912038
# iteration 2100 / 2196: loss 1.096764
# Validation accuracy:  0.559

# %%
# Run your neural net classifier on the test set. You should be able to
# get more than 55% accuracy.

test_acc = (best_net.predict(X_test_feats) == y_test).mean()
print test_acc
# Out:
# 0.575
